# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings('ignore')
from bayes_lin_regr import *

# %%
preds = main(itr=10000)
# Out:
# Loading data
# Running SVI for 10000 iterations
# Iter 0, loss = 74135.6
# Iter 50, loss = 57586.2
# Iter 100, loss = 59151.1
# Iter 150, loss = 55408.8
# Iter 200, loss = 51385.2
# Iter 250, loss = 45244.4
# Iter 300, loss = 46432.9
# Iter 350, loss = 38309
# Iter 400, loss = 39535.4
# Iter 450, loss = 38065.7
# Iter 500, loss = 33196.2
# Iter 550, loss = 30007.7
# Iter 600, loss = 29191.9
# Iter 650, loss = 29194.3
# Iter 700, loss = 27220.9
# Iter 750, loss = 27962.5
# Iter 800, loss = 26211.3
# Iter 850, loss = 25946.5
# Iter 900, loss = 23529.5
# Iter 950, loss = 23256.8
# Iter 1000, loss = 25085.6
# Iter 1050, loss = 22864.1
# Iter 1100, loss = 24075.2
# Iter 1150, loss = 22498.4
# Iter 1200, loss = 23759.4
# Iter 1250, loss = 22569.2
# Iter 1300, loss = 22760.3
# Iter 1350, loss = 21188.4
# Iter 1400, loss = 22971.9
# Iter 1450, loss = 23535.4
# Iter 1500, loss = 21587.3
# Iter 1550, loss = 22352.3
# Iter 1600, loss = 20674
# Iter 1650, loss = 22767.6
# ...
