# %%
import numpy as np
import pandas as pd
import torch

# %%
def preprocess():
    data = pd.read_csv("/mnt/d/mlpp/nyse/data_fund.csv")
    fun = data.loc[~data['Indicator Name'].isin(['Common Shares Outstanding','Share Price'])].reset_index(drop=True)
    fun['yyyymm']=pd.to_datetime(fun['publish date'])
    fun = pd.pivot_table(fun, values='Indicator Value', index=['Ticker', 'yyyymm'],columns=['Indicator Name'], aggfunc=np.mean).reset_index()

    to_remove = ['Ticker','yyyymm','Avg. Basic Shares Outstanding','Avg. Diluted Shares Outstanding','Total Assets']
    fun_cols = list(fun.columns)
    for elem in to_remove:
        fun_cols.remove(elem)

    fun[fun_cols] = fun[fun_cols].div(fun['Total Assets'], axis=0).reset_index(drop=True)

    features = fun[fun_cols+['yyyymm','Ticker']]
    features = features.dropna().reset_index(drop=True)
    features = features.fillna(0).reset_index(drop=True)

    zscore = lambda x: (x - x.mean()) / x.std()
    final = features[['Ticker','yyyymm']]
    for item in fun_cols:
        temp = features.groupby([features.yyyymm])[item].transform(zscore)
        final = pd.concat([final,temp], axis=1).reset_index(drop=True)

    data['publish date']=pd.to_datetime(data['publish date'])
    rtns = data.loc[data['Indicator Name']=='Share Price', ['Ticker','publish date','Company Industry Classification Code', 'Indicator Value']].reset_index(drop=True)
    rtns.columns = ['Ticker','Date','Industry','Price']
    rtns['Rtn1d'] = rtns.groupby('Ticker')['Price'].apply(lambda x: np.log(x).diff())
    rtns['Rtn1q'] = rtns.groupby('Ticker')['Rtn1d'].rolling(63).sum().shift(-63).reset_index(0,drop=True)
    rtns['Rtn1d'] = rtns.groupby('Ticker')['Rtn1d'].shift(-1).reset_index(0,drop=True)
    rtns.dropna(inplace=True)

    final = final.merge(rtns, left_on=['Ticker','yyyymm'], right_on =['Ticker','Date'],how='inner').reset_index(0,drop=True)
    final.dropna(inplace=True)
    train = final[final['yyyymm']<='2016-12-31'].reset_index(0,drop=True)
    test = final[final['yyyymm']>'2016-12-31'].reset_index(0,drop=True)

    X_train = train[fun_cols].values
    y_train = train['Rtn1q'].values
    X_test = test[fun_cols].values
    y_test = test['Rtn1q'].values
    X_tr = torch.tensor(X_train, dtype=torch.float)
    y_tr = torch.tensor(y_train, dtype=torch.float)
    X_ts = torch.tensor(X_test, dtype=torch.float)
    y_ts = torch.tensor(y_test, dtype=torch.float)

    return train

# %%
data = preprocess()
# Out:
# /mnt/c/Users/aksmi/Desktop/Drive/Fall '19/Courses/ML with Probabilistic Programming/course_repo/probprog/lib/python3.6/site-packages/pandas/core/series.py:853: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /mnt/c/Users/aksmi/Desktop/Drive/Fall '19/Courses/ML with Probabilistic Programming/course_repo/probprog/lib/python3.6/site-packages/pandas/core/algorithms.py:1977: RuntimeWarning: invalid value encountered in subtract
#   out_arr[res_indexer] = arr[res_indexer] - arr[lag_indexer]

# %%
orig_cols = list(data.columns)
orig_cols
# Out:
# ['Ticker',
#  'yyyymm',
#  'Accounts Payable',
#  'COGS',
#  'Cash From Financing Activities',
#  'Cash From Investing Activities',
#  'Cash From Operating Activities',
#  'Cash and Cash Equivalents',
#  'Current Assets',
#  'Current Liabilities',
#  'Dividends',
#  'EBIT',
#  'EBITDA',
#  'Equity Before Minorities',
#  'Goodwill',
#  'Intangible Assets',
#  'Long Term Debt',
#  'Minorities',
#  'Net Change in Cash',
#  'Net Income from Discontinued Op.',
#  'Net PP&E',
#  'Net Profit',
#  'Preferred Equity',
#  'Receivables',
#  'Retained Earnings',
#  'Revenues',
#  'SG&A',
#  'Share Capital',
#  'Short term debt',
#  'Total Equity',
#  'Total Liabilities',
#  'Total Noncurrent Assets',
#  'Total Noncurrent Liabilities',
#  'Treasury Stock',
#  'Date',
#  'Industry',
#  'Price',
#  'Rtn1d',
#  'Rtn1q']

# %%
cor = data.corr()
df1 = cor.stack().reset_index()
df1.columns = ['v1','v2','correlation']

# %%
df1[(np.abs(df1.correlation) > 0.7) & (df1.v1 != df1.v2)]
# Out:
#                                   v1                              v2  \
# 59                              COGS                        Revenues
# 153   Cash From Operating Activities                            EBIT
# 154   Cash From Operating Activities                          EBITDA
# 186        Cash and Cash Equivalents                  Current Assets
# 221                   Current Assets       Cash and Cash Equivalents
# 245                   Current Assets         Total Noncurrent Assets
# 328                             EBIT  Cash From Operating Activities
# 334                             EBIT                          EBITDA
# 343                             EBIT                      Net Profit
# 364                           EBITDA  Cash From Operating Activities
# 369                           EBITDA                            EBIT
# 379                           EBITDA                      Net Profit
# 423         Equity Before Minorities                    Total Equity
# 424         Equity Before Minorities               Total Liabilities
# 534                   Long Term Debt    Total Noncurrent Liabilities
# 693                       Net Profit                            EBIT
# 694                       Net Profit                          EBITDA
# 817                Retained Earnings                   Share Capital
# 829                         Revenues                            COGS
# 922                    Share Capital               Retained Earnings
# 983                     Total Equity        Equity Before Minorities
# 1000                    Total Equity               Total Liabilities
# 1002                    Total Equity    Total Noncurrent Liabilities
# 1019               Total Liabilities        Equity Before Minorities
# 1035               Total Liabilities                    Total Equity
# 1038               Total Liabilities    Total Noncurrent Liabilities
# 1050         Total Noncurrent Assets                  Current Assets
# 1094    Total Noncurrent Liabilities                  Long Term Debt
# 1107    Total Noncurrent Liabilities                    Total Equity
# 1108    Total Noncurrent Liabilities               Total Liabilities
#
#       correlation
# 59       0.920643
# 153      0.790660
# 154      0.822364
# 186      0.701276
# 221      0.701276
# 245     -0.994792
# 328      0.790660
# 334      0.960648
# 343      0.793430
# 364      0.822364
# 369      0.960648
# 379      0.741451
# 423      0.974447
# 424     -0.913043
# 534      0.842667
# 693      0.793430
# 694      0.741451
# 817     -0.870512
# 829      0.920643
# 922     -0.870512
# 983      0.974447
# 1000    -0.937604
# 1002    -0.709382
# 1019    -0.913043
# 1035    -0.937604
# 1038     0.757171
# 1050    -0.994792
# 1094     0.842667
# 1107    -0.709382
# 1108     0.757171

# %%
to_remove = ['COGS', 'EBIT', 'Cash From Operating Activities', 'Cash and Cash Equivalents', 
             'Net Profit', 'Equity Before Minorities', 'Total Noncurrent Liabilities', 'Total Equity', 
             'Total Noncurrent Assets', 'Industry', 'Price', 'Retained Earnings']
new_data = data.drop(columns=to_remove)
new_data
# Out:
#       Ticker     yyyymm  Accounts Payable  Cash From Financing Activities  \
# 0          A 2011-09-07         -0.684551                       -1.691360
# 1          A 2012-09-05         -0.709434                        0.260642
# 2          A 2013-09-06         -1.033439                        0.065106
# 3          A 2014-03-05         -0.650589                       -0.408724
# 4          A 2015-09-02         -0.856860                       -0.671772
# ...      ...        ...               ...                             ...
# 23783   ZYXI 2013-11-13         -0.237443                       -0.416832
# 23784   ZYXI 2014-03-28          0.565673                       -0.351831
# 23785   ZYXI 2014-05-13         -0.097035                       -0.417585
# 23786   ZYXI 2014-11-07          3.552294                       -1.410148
# 23787   ZYXI 2015-03-31          0.890030                       -0.415715
#
#        Cash From Investing Activities  Current Assets  Current Liabilities  \
# 0                            2.183893        0.121045            -0.742225
# 1                           -1.493651       -0.534877            -0.282426
# 2                            0.645516       -0.383689            -0.593869
# 3                           -0.077143       -0.469958            -0.854185
# 4                            0.926701       -0.967320            -0.941585
# ...                               ...             ...                  ...
# 23783                        0.541170        0.930020            -0.104267
# 23784                        0.610385        1.108777            -0.239761
# 23785                        0.377210        0.374856            -0.178736
# 23786                        1.341371        1.258234             3.650075
# 23787                        0.357295        0.727574             0.772516
#
#        Dividends    EBITDA  Goodwill  ...  Receivables  Revenues      SG&A  \
# 0       1.040803 -0.303176  1.084159  ...     0.277094 -0.565718  0.020479
# 1       0.376062 -0.066381  0.881559  ...     0.006782 -0.920759 -0.866846
# 2       0.458310 -0.356593  0.940296  ...    -0.116874 -0.907514 -0.024056
# 3      -0.301951  0.158868  0.770338  ...    -0.473313 -0.905179 -0.689553
# 4      -0.463685  0.428915  1.616694  ...     0.153932 -0.691456 -0.549809
# ...          ...       ...       ...  ...          ...       ...       ...
# 23783   0.301188  0.164521 -0.545100  ...     1.375865  0.027230  0.677736
# 23784   0.422062  0.224183 -0.707606  ...     2.152397  0.265088 -0.108890
# 23785   0.361651  0.157924 -0.478034  ...     2.047916 -0.197993 -0.038350
# 23786   0.433900 -4.364331 -0.828080  ...     3.709134  0.203122  5.348564
# 23787   0.458756  0.093233 -0.596567  ...     2.724340  0.005373  0.093524
#
#        Share Capital  Short term debt  Total Liabilities  Treasury Stock  \
# 0           2.773964        -0.558649          -0.096951       -1.484969
# 1          -0.227864         1.056813          -0.129860       -3.265011
# 2           0.307529        -0.606792           0.160705       -1.309986
# 3          -0.232574        -0.647795          -0.156960       -3.804480
# 4           0.096287        -0.528900          -0.453045       -1.788469
# ...              ...              ...                ...             ...
# 23783      -0.325424        -0.277523          -0.186476        0.277342
# 23784      -0.242659        -0.178590          -0.240793        0.469490
# 23785      -0.171635        -0.199940          -0.178264        0.298874
# 23786      -0.114953        -0.237932           2.634953        0.338649
# 23787      -0.350504        -0.375252           0.021042        0.238510
#
#             Date     Rtn1d         Rtn1q
# 0     2011-09-07 -0.044433  3.571075e-02
# 1     2012-09-05  0.019993  4.462735e-02
# 2     2013-09-06  0.011084  1.227928e-01
# 3     2014-03-05  0.016550 -3.799878e-03
# 4     2015-09-02  0.006125  1.316645e-01
# ...          ...       ...           ...
# 23783 2013-11-13  0.182322  5.108256e-01
# 23784 2014-03-28  0.000000 -6.899287e-02
# 23785 2014-05-13 -0.044452 -6.661338e-16
# 23786 2014-11-07  0.057158 -6.062462e-02
# 23787 2015-03-31  0.068993  3.566749e-01
#
# [23788 rows x 27 columns]

# %%
cor = new_data.corr()
df1 = cor.stack().reset_index()
df1.columns = ['v1','v2','correlation']

# %%
new_data.columns
# Out:
# Index(['Ticker', 'yyyymm', 'Accounts Payable',
#        'Cash From Financing Activities', 'Cash From Investing Activities',
#        'Current Assets', 'Current Liabilities', 'Dividends', 'EBITDA',
#        'Goodwill', 'Intangible Assets', 'Long Term Debt', 'Minorities',
#        'Net Change in Cash', 'Net Income from Discontinued Op.', 'Net PP&E',
#        'Preferred Equity', 'Receivables', 'Revenues', 'SG&A', 'Share Capital',
#        'Short term debt', 'Total Liabilities', 'Treasury Stock', 'Date',
#        'Rtn1d', 'Rtn1q'],
#       dtype='object')
